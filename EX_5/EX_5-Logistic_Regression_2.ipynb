# %% [markdown]
# <b><h1 style="font-size:30px;text-align: center;">- Data Analytics in Cloud Computing  - Exercise 5 -</h1></b>
# <b><h1 style="font-size:25px;text-align: center;">- Logistic Regression - 2 -</h1></b>
#
#
#
# <div style="text-align:center; margin:16px 0 28px;">
#   <img
#     src="https://futsal-dinamo.hr/wp-content/uploads/2021/01/Algebra-Bernays.png"
#     alt="Algebra Bernays"
#     style="width:600px; max-width:60%; height:auto; margin-top:25px;"
#   >
# </div>
#
#
#
# ---------------------
#
# <b>*Made: April 2026.* </b>
#
# <b>*Author: Adjunct Lecturer Mislav Spajić, M.Eng. (Comp.)*</b>
#
# ---------------------

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression

# %%
data = {
    "FIRST": [1, 0, 1, 1, 1, 1, 0, 1],
    "SECOND": [1, 1, 0, 0, 0, 1, 1, 1],
    "THRID": [1, 1, 0, 0, 0, 1, 0, 1],
    "TARGET": [1, 0, 0, 0, 0, 1, 0, 1]
}

df = pd.DataFrame(data)
print(df)

# %%
X, y = df.iloc[:,:-1], df.iloc[:, -1]
print(X)

# %%
model = LogisticRegression(fit_intercept = True)
mdl = model.fit(X, y)

# Check trained model intercept
print(mdl.intercept_)

# Check trained model coefficients
print(mdl.coef_)

# %%
preds = model.predict(X)
preds
